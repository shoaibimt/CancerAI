# %% [markdown]
# <a href="https://colab.research.google.com/github/shoaibimt/CancerAI/blob/main/file_1_chembl_data_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-08-12 05:16:23--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   243MB/s    in 0.3s
#
# 2022-08-12 05:16:23 (243 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.3 MB/s
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/site-packages (from chembl_webresource_client) (2.22.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/site-packages (from chembl_webresource_client) (1.25.8)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Collecting easydict
#   Downloading easydict-1.9.tar.gz (6.4 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 7.3 MB/s
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.9 MB/s
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.14.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6349 sha256=db45865fe8fb946ffb7d958d4a05385cc61115a128418dfcf4425cc03bd4aabf
#   Stored in directory: /root/.cache/pip/wheels/88/96/68/c2be18e7406804be2e593e1c37845f2dd20ac2ce1381ce40b0
# Successfully built easydict
# Installing collected packages: attrs, itsdangerous, pyyaml, url-normalize, requests-cache, easydict, chembl-webresource-client
# Successfully installed attrs-21.4.0 chembl-webresource-client-0.10.8 easydict-1.9 itsdangerous-2.1.2 pyyaml-6.0 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
import numpy as np
import math
from pathlib import Path
from zipfile import ZipFile
from tempfile import TemporaryDirectory
from chembl_webresource_client.new_client import new_client
from tqdm.auto import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
target = new_client.target
target_query = target.search('BCR-ABL')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'A1Z199', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P00521', 'xref_name': None, 'xre...
# 6                                                  []
# 7                                                  []
# 8   [{'xref_id': 'P00519', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P00520', 'xref_name': None, 'xre...
# 10                                                 []
# 11  [{'xref_id': 'P11274', 'xref_name': None, 'xre...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
#
#                          organism  \
# 0                    Homo sapiens
# 1                    Homo sapiens
# 2                    Mus musculus
# 3                    Homo sapiens
# 4                    Homo sapiens
# 5   Abelson murine leukemia virus
# 6                    Homo sapiens
# 7                    Homo sapiens
# 8                    Homo sapiens
# 9                    Mus musculus
# 10                   Homo sapiens
# 11                   Homo sapiens
# 12                   Homo sapiens
# 13                   Homo sapiens
# 14                   Homo sapiens
# 15                   Homo sapiens
# 16                   Homo sapiens
#
#                                             pref_name  score  \
# 0                         BCR/ABL p210 fusion protein   36.0
# 1                                    Cereblon/BCR/ABL   25.0
# 2                                            BCR/ABL1   24.0
# 3                              Bcr/Abl fusion protein   22.0
# 4                                        VHL/BCR-ABL1   19.0
# 5                       Tyrosine-protein kinase V-ABL   18.0
# 6            E3 ubiquitin-protein ligase XIAP/BCR/ABL   17.0
# 7   Baculoviral IAP repeat-containing protein 2/BC...   16.0
# 8                         Tyrosine-protein kinase ABL   14.0
# 9                         Tyrosine-protein kinase ABL   14.0
# 10      Protein cereblon/Tyrosine-protein kinase ABL1   14.0
# 11                  Breakpoint cluster region protein   13.0
# 12                                           VHL/ABL1   13.0
# 13  Ras and Rab interactor 1/Tyrosine-protein kina...   12.0
# 14  Transcription factor ETV6/Tyrosine-protein kin...   12.0
# 15                        Tyrosine-protein kinase ABL   11.0
# 16              B-cell receptor-associated protein 31   11.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL6105
# 1                False    CHEMBL4296137
# 2                False    CHEMBL4523652
# 3                False    CHEMBL2096618
# 4                False    CHEMBL4523751
# 5                False       CHEMBL5166
# 6                False    CHEMBL4296120
# 7                False    CHEMBL4296119
# 8                False       CHEMBL1862
# 9                False       CHEMBL3099
# 10               False    CHEMBL4523750
# 11               False       CHEMBL5146
# 12               False    CHEMBL4523725
# 13               False    CHEMBL3885630
# 14               False    CHEMBL3885645
# 15               False    CHEMBL2111414
# 16               False    CHEMBL4295778
#
#                                     target_components  \
# 0   [{'accession': 'A1Z199', 'component_descriptio...
# 1   [{'accession': 'P00519', 'component_descriptio...
# 2   [{'accession': 'P00520', 'component_descriptio...
# 3   [{'accession': 'P00519', 'component_descriptio...
# 4   [{'accession': 'P00519', 'component_descriptio...
# 5   [{'accession': 'P00521', 'component_descriptio...
# 6   [{'accession': 'P00519', 'component_descriptio...
# 7   [{'accession': 'P00519', 'component_descriptio...
# 8   [{'accession': 'P00519', 'component_descriptio...
# 9   [{'accession': 'P00520', 'component_descriptio...
# 10  [{'accession': 'P00519', 'component_descriptio...
# 11  [{'accession': 'P11274', 'component_descriptio...
# 12  [{'accession': 'P00519', 'component_descriptio...
# 13  [{'accession': 'P00519', 'component_descriptio...
# 14  [{'accession': 'P00519', 'component_descriptio...
# 15  [{'accession': 'P00519', 'component_descriptio...
# 16  [{'accession': 'P51572', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN    9606
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2              CHIMERIC PROTEIN   10090
# 3              CHIMERIC PROTEIN    9606
# 4   PROTEIN-PROTEIN INTERACTION    9606
# 5                SINGLE PROTEIN   11788
# 6   PROTEIN-PROTEIN INTERACTION    9606
# 7   PROTEIN-PROTEIN INTERACTION    9606
# 8                SINGLE PROTEIN    9606
# 9                SINGLE PROTEIN   10090
# 10  PROTEIN-PROTEIN INTERACTION    9606
# 11               SINGLE PROTEIN    9606
# 12  PROTEIN-PROTEIN INTERACTION    9606
# 13  PROTEIN-PROTEIN INTERACTION    9606
# 14             CHIMERIC PROTEIN    9606
# 15               PROTEIN FAMILY    9606
# 16               SINGLE PROTEIN    9606

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL2096618'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.shape
# Out:
# (683, 45)

# %%
pd.set_option('display.max_columns', 45)

# %%
df
# Out:
#     activity_comment  activity_id  \
# 0               None      1675266
# 1     Not Determined      1675350
# 2               None      1675351
# 3               None      1675352
# 4               None      1675353
# ..               ...          ...
# 678             None     22989344
# 679             None     22989345
# 680             None     22989346
# 681             None     22989347
# 682             None     22989348
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL867071
# 1                                                   []    CHEMBL867071
# 2                                                   []    CHEMBL867071
# 3                                                   []    CHEMBL867071
# 4                                                   []    CHEMBL867071
# ..                                                 ...             ...
# 678  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 679  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 680  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 681  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 682  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
#
#                                      assay_description assay_type  \
# 0    Antiproliferative activity against human BCR-A...          F
# 1    Antiproliferative activity against human BCR-A...          F
# 2    Antiproliferative activity against human BCR-A...          F
# 3    Antiproliferative activity against human BCR-A...          F
# 4    Antiproliferative activity against human BCR-A...          F
# ..                                                 ...        ...
# 678  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 679  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 680  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 681  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 682  Inhibition of BCR-ABL T315I mutant (unknown or...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000219
# 1                      None                   None  BAO_0000190  BAO_0000219
# 2                      None                   None  BAO_0000190  BAO_0000219
# 3                      None                   None  BAO_0000190  BAO_0000219
# 4                      None                   None  BAO_0000190  BAO_0000219
# ..                      ...                    ...          ...          ...
# 678                  P00519                  T315I  BAO_0000179  BAO_0000224
# 679                  P00519                  T315I  BAO_0000179  BAO_0000224
# 680                  P00519                  T315I  BAO_0000179  BAO_0000224
# 681                  P00519                  T315I  BAO_0000179  BAO_0000224
# 682                  P00519                  T315I  BAO_0000179  BAO_0000224
#
#              bao_label                                   canonical_smiles  \
# 0    cell-based format  CN1CCN(CCc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc...
# 1    cell-based format  COc1ccc(-c2cnc(O)c(C(=O)Nc3ccc(CN4CCN(C)CC4)cc...
# 2    cell-based format  CN1CCN(CCCc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cn...
# 3    cell-based format  CN1CCN(Cc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc3...
# 4    cell-based format  CN1CCN(c2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc3O...
# ..                 ...                                                ...
# 678     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4cc(CN5CCOCC5)...
# 679     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4ccc(Cl)c(C(F)...
# 680     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4ccc(CN5CCOCC5...
# 681     protein format  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 682     protein format  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
#
#     data_validity_comment data_validity_description document_chembl_id  \
# 0                    None                      None      CHEMBL1149386
# 1                    None                      None      CHEMBL1149386
# 2                    None                      None      CHEMBL1149386
# 3                    None                      None      CHEMBL1149386
# 4                    None                      None      CHEMBL1149386
# ..                    ...                       ...                ...
# 678                  None                      None      CHEMBL4765455
# 679                  None                      None      CHEMBL4765455
# 680                  None                      None      CHEMBL4765455
# 681                  None                      None      CHEMBL4765455
# 682                  None                      None      CHEMBL4765455
#
#     document_journal  document_year  \
# 0      J. Med. Chem.           2006
# 1      J. Med. Chem.           2006
# 2      J. Med. Chem.           2006
# 3      J. Med. Chem.           2006
# 4      J. Med. Chem.           2006
# ..               ...            ...
# 678   Eur J Med Chem           2020
# 679   Eur J Med Chem           2020
# 680   Eur J Med Chem           2020
# 681   Eur J Med Chem           2020
# 682   Eur J Med Chem           2020
#
#                                      ligand_efficiency molecule_chembl_id  \
# 0                                                 None       CHEMBL199723
# 1                                                 None       CHEMBL203354
# 2                                                 None       CHEMBL381738
# 3                                                 None       CHEMBL370800
# 4                                                 None       CHEMBL436509
# ..                                                 ...                ...
# 678  {'bei': '10.78', 'le': '0.20', 'lle': '0.95', ...      CHEMBL4794284
# 679  {'bei': '12.86', 'le': '0.25', 'lle': '0.38', ...      CHEMBL4786855
# 680  {'bei': '11.15', 'le': '0.21', 'lle': '1.14', ...      CHEMBL4776468
# 681                                               None          CHEMBL941
# 682  {'bei': '15.55', 'le': '0.28', 'lle': '2.90', ...       CHEMBL388978
#
#     molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                 None              CHEMBL199723          5.02
# 1                 None              CHEMBL203354          None
# 2                 None              CHEMBL381738          4.84
# 3                 None              CHEMBL370800          4.89
# 4                 None              CHEMBL436509          5.42
# ..                 ...                       ...           ...
# 678               None             CHEMBL4794284          5.60
# 679               None             CHEMBL4786855          5.85
# 680               None             CHEMBL4776468          5.79
# 681           IMATINIB                 CHEMBL941          None
# 682      STAUROSPORINE              CHEMBL388978          7.25
#
#      potential_duplicate                                 qudt_units  \
# 0                      0  http://www.openphacts.org/units/Nanomolar
# 1                      0                                       None
# 2                      0  http://www.openphacts.org/units/Nanomolar
# 3                      0  http://www.openphacts.org/units/Nanomolar
# 4                      0  http://www.openphacts.org/units/Nanomolar
# ..                   ...                                        ...
# 678                    0                                       None
# 679                    0                                       None
# 680                    0                                       None
# 681                    0                                       None
# 682                    0                                       None
#
#      record_id relation  src_id  standard_flag standard_relation  \
# 0       422295        =       1              1                 =
# 1       422299     None       1              0              None
# 2       422298        =       1              1                 =
# 3       422297        =       1              1                 =
# 4       422296        =       1              1                 =
# ..         ...      ...     ...            ...               ...
# 678    3570423        =       1              1                 =
# 679    3570424        =       1              1                 =
# 680    3570425        =       1              1                 =
# 681    3570426        >       1              1                 >
# 682    3570427        =       1              1                 =
#
#     standard_text_value standard_type standard_units standard_upper_value  \
# 0                  None          IC50             nM                 None
# 1                  None          IC50           None                 None
# 2                  None          IC50             nM                 None
# 3                  None          IC50             nM                 None
# 4                  None          IC50             nM                 None
# ..                  ...           ...            ...                  ...
# 678                None          IC50             nM                 None
# 679                None          IC50             nM                 None
# 680                None          IC50             nM                 None
# 681                None          IC50             nM                 None
# 682                None          IC50             nM                 None
#
#     standard_value target_chembl_id target_organism        target_pref_name  \
# 0           9500.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 1             None    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 2          14600.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 3          12900.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 4           3800.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# ..             ...              ...             ...                     ...
# 678         2510.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 679         1420.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 680         1605.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 681       100000.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 682           55.7    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
#
#     target_tax_id text_value  toid  type units    uo_units upper_value   value
# 0            9606       None  None  IC50    uM  UO_0000065        None     9.5
# 1            9606       None  None  IC50  None        None        None    None
# 2            9606       None  None  IC50    uM  UO_0000065        None    14.6
# 3            9606       None  None  IC50    uM  UO_0000065        None    12.9
# 4            9606       None  None  IC50    uM  UO_0000065        None     3.8
# ..            ...        ...   ...   ...   ...         ...         ...     ...
# 678          9606       None  None  IC50    uM        None        None    2.51
# 679          9606       None  None  IC50    uM        None        None    1.42
# 680          9606       None  None  IC50    uM        None        None   1.605
# 681          9606       None  None  IC50    uM        None        None   100.0
# 682          9606       None  None  IC50    uM        None        None  0.0557
#
# [683 rows x 45 columns]

# %%
df.to_csv('bcr_abl_bioactivity_data_raw.csv', index=False)

# %%
cp bcr_abl_bioactivity_data_raw.csv '/content/drive/MyDrive/inhibitor_prediction/bcr_abl/chembl_data_retrieve'

# %%
path = ('/content/drive/MyDrive/inhibitor_prediction/bcr_abl/chembl_data_retrieve/bcr_abl_bioactivity_data_raw.csv')

# %%
pd.read_csv(path)
# Out:
#     activity_comment  activity_id  \
# 0                NaN      1675266
# 1     Not Determined      1675350
# 2                NaN      1675351
# 3                NaN      1675352
# 4                NaN      1675353
# ..               ...          ...
# 678              NaN     22989344
# 679              NaN     22989345
# 680              NaN     22989346
# 681              NaN     22989347
# 682              NaN     22989348
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL867071
# 1                                                   []    CHEMBL867071
# 2                                                   []    CHEMBL867071
# 3                                                   []    CHEMBL867071
# 4                                                   []    CHEMBL867071
# ..                                                 ...             ...
# 678  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 679  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 680  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 681  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
# 682  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4774928
#
#                                      assay_description assay_type  \
# 0    Antiproliferative activity against human BCR-A...          F
# 1    Antiproliferative activity against human BCR-A...          F
# 2    Antiproliferative activity against human BCR-A...          F
# 3    Antiproliferative activity against human BCR-A...          F
# 4    Antiproliferative activity against human BCR-A...          F
# ..                                                 ...        ...
# 678  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 679  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 680  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 681  Inhibition of BCR-ABL T315I mutant (unknown or...          B
# 682  Inhibition of BCR-ABL T315I mutant (unknown or...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       NaN                    NaN  BAO_0000190  BAO_0000219
# 1                       NaN                    NaN  BAO_0000190  BAO_0000219
# 2                       NaN                    NaN  BAO_0000190  BAO_0000219
# 3                       NaN                    NaN  BAO_0000190  BAO_0000219
# 4                       NaN                    NaN  BAO_0000190  BAO_0000219
# ..                      ...                    ...          ...          ...
# 678                  P00519                  T315I  BAO_0000179  BAO_0000224
# 679                  P00519                  T315I  BAO_0000179  BAO_0000224
# 680                  P00519                  T315I  BAO_0000179  BAO_0000224
# 681                  P00519                  T315I  BAO_0000179  BAO_0000224
# 682                  P00519                  T315I  BAO_0000179  BAO_0000224
#
#              bao_label                                   canonical_smiles  \
# 0    cell-based format  CN1CCN(CCc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc...
# 1    cell-based format  COc1ccc(-c2cnc(O)c(C(=O)Nc3ccc(CN4CCN(C)CC4)cc...
# 2    cell-based format  CN1CCN(CCCc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cn...
# 3    cell-based format  CN1CCN(Cc2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc3...
# 4    cell-based format  CN1CCN(c2ccc(NC(=O)c3cc(-c4ccc5c(c4)OCO5)cnc3O...
# ..                 ...                                                ...
# 678     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4cc(CN5CCOCC5)...
# 679     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4ccc(Cl)c(C(F)...
# 680     protein format  Nc1n[nH]c2cccc(C#Cc3cccc(C(=O)Nc4ccc(CN5CCOCC5...
# 681     protein format  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 682     protein format  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
#
#     data_validity_comment data_validity_description document_chembl_id  \
# 0                     NaN                       NaN      CHEMBL1149386
# 1                     NaN                       NaN      CHEMBL1149386
# 2                     NaN                       NaN      CHEMBL1149386
# 3                     NaN                       NaN      CHEMBL1149386
# 4                     NaN                       NaN      CHEMBL1149386
# ..                    ...                       ...                ...
# 678                   NaN                       NaN      CHEMBL4765455
# 679                   NaN                       NaN      CHEMBL4765455
# 680                   NaN                       NaN      CHEMBL4765455
# 681                   NaN                       NaN      CHEMBL4765455
# 682                   NaN                       NaN      CHEMBL4765455
#
#     document_journal  document_year  \
# 0      J. Med. Chem.           2006
# 1      J. Med. Chem.           2006
# 2      J. Med. Chem.           2006
# 3      J. Med. Chem.           2006
# 4      J. Med. Chem.           2006
# ..               ...            ...
# 678   Eur J Med Chem           2020
# 679   Eur J Med Chem           2020
# 680   Eur J Med Chem           2020
# 681   Eur J Med Chem           2020
# 682   Eur J Med Chem           2020
#
#                                      ligand_efficiency molecule_chembl_id  \
# 0                                                  NaN       CHEMBL199723
# 1                                                  NaN       CHEMBL203354
# 2                                                  NaN       CHEMBL381738
# 3                                                  NaN       CHEMBL370800
# 4                                                  NaN       CHEMBL436509
# ..                                                 ...                ...
# 678  {'bei': '10.78', 'le': '0.20', 'lle': '0.95', ...      CHEMBL4794284
# 679  {'bei': '12.86', 'le': '0.25', 'lle': '0.38', ...      CHEMBL4786855
# 680  {'bei': '11.15', 'le': '0.21', 'lle': '1.14', ...      CHEMBL4776468
# 681                                                NaN          CHEMBL941
# 682  {'bei': '15.55', 'le': '0.28', 'lle': '2.90', ...       CHEMBL388978
#
#     molecule_pref_name parent_molecule_chembl_id  pchembl_value  \
# 0                  NaN              CHEMBL199723           5.02
# 1                  NaN              CHEMBL203354            NaN
# 2                  NaN              CHEMBL381738           4.84
# 3                  NaN              CHEMBL370800           4.89
# 4                  NaN              CHEMBL436509           5.42
# ..                 ...                       ...            ...
# 678                NaN             CHEMBL4794284           5.60
# 679                NaN             CHEMBL4786855           5.85
# 680                NaN             CHEMBL4776468           5.79
# 681           IMATINIB                 CHEMBL941            NaN
# 682      STAUROSPORINE              CHEMBL388978           7.25
#
#      potential_duplicate                                 qudt_units  \
# 0                      0  http://www.openphacts.org/units/Nanomolar
# 1                      0                                        NaN
# 2                      0  http://www.openphacts.org/units/Nanomolar
# 3                      0  http://www.openphacts.org/units/Nanomolar
# 4                      0  http://www.openphacts.org/units/Nanomolar
# ..                   ...                                        ...
# 678                    0                                        NaN
# 679                    0                                        NaN
# 680                    0                                        NaN
# 681                    0                                        NaN
# 682                    0                                        NaN
#
#      record_id relation  src_id  standard_flag standard_relation  \
# 0       422295        =       1              1                 =
# 1       422299      NaN       1              0               NaN
# 2       422298        =       1              1                 =
# 3       422297        =       1              1                 =
# 4       422296        =       1              1                 =
# ..         ...      ...     ...            ...               ...
# 678    3570423        =       1              1                 =
# 679    3570424        =       1              1                 =
# 680    3570425        =       1              1                 =
# 681    3570426        >       1              1                 >
# 682    3570427        =       1              1                 =
#
#      standard_text_value standard_type standard_units  standard_upper_value  \
# 0                    NaN          IC50             nM                   NaN
# 1                    NaN          IC50            NaN                   NaN
# 2                    NaN          IC50             nM                   NaN
# 3                    NaN          IC50             nM                   NaN
# 4                    NaN          IC50             nM                   NaN
# ..                   ...           ...            ...                   ...
# 678                  NaN          IC50             nM                   NaN
# 679                  NaN          IC50             nM                   NaN
# 680                  NaN          IC50             nM                   NaN
# 681                  NaN          IC50             nM                   NaN
# 682                  NaN          IC50             nM                   NaN
#
#      standard_value target_chembl_id target_organism        target_pref_name  \
# 0            9500.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 1               NaN    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 2           14600.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 3           12900.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 4            3800.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# ..              ...              ...             ...                     ...
# 678          2510.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 679          1420.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 680          1605.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 681        100000.0    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
# 682            55.7    CHEMBL2096618    Homo sapiens  Bcr/Abl fusion protein
#
#      target_tax_id  text_value  toid  type units    uo_units  upper_value  \
# 0             9606         NaN   NaN  IC50    uM  UO_0000065          NaN
# 1             9606         NaN   NaN  IC50   NaN         NaN          NaN
# 2             9606         NaN   NaN  IC50    uM  UO_0000065          NaN
# 3             9606         NaN   NaN  IC50    uM  UO_0000065          NaN
# 4             9606         NaN   NaN  IC50    uM  UO_0000065          NaN
# ..             ...         ...   ...   ...   ...         ...          ...
# 678           9606         NaN   NaN  IC50    uM         NaN          NaN
# 679           9606         NaN   NaN  IC50    uM         NaN          NaN
# 680           9606         NaN   NaN  IC50    uM         NaN          NaN
# 681           9606         NaN   NaN  IC50    uM         NaN          NaN
# 682           9606         NaN   NaN  IC50    uM         NaN          NaN
#
#         value
# 0      9.5000
# 1         NaN
# 2     14.6000
# 3     12.9000
# 4      3.8000
# ..        ...
# 678    2.5100
# 679    1.4200
# 680    1.6050
# 681  100.0000
# 682    0.0557
#
# [683 rows x 45 columns]
